# %%
import requests

# %%
url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/rankings/batsmen"

querystring = {"formatType":"odi"}

headers = {
	"X-RapidAPI-Key": "fc69733edbmsh9bdf2f51eb88710p14a0cdjsn7db96e5af297",
	"X-RapidAPI-Host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
if response.status_code==200:
    response_data = response.json()
else:
    raise(f'error fetching response:\n{response}')

# %%
import pandas as pd

df = pd.json_normalize(response_data['rank'], max_level=0)
df
# Out:
#        id rank                   name       country rating points  \
# 0    8359    1             Babar Azam      Pakistan    824    824
# 1   11808    2           Shubman Gill         India    801    801
# 2    1413    3            Virat Kohli         India    768    768
# 3     576    4           Rohit Sharma         India    746    746
# 4   11130    4           Harry Tector       Ireland    746    746
# 5   10713    6         Daryl Mitchell   New Zealand    728    728
# 6    1739    7           David Warner     Australia    723    723
# 7   13682    8        Pathum Nissanka     Sri Lanka    711    711
# 8    6660    9            Dawid Malan       England    707    707
# 9    9554   10  Rassie van der Dussen  South Africa    701    701
# 10  10209   11       Heinrich Klaasen  South Africa    697    697
# 11   9428   12           Shreyas Iyer         India    689    689
# 12  10863   13           Fakhar Zaman      Pakistan    682    682
# ...

# %%
response_data['rank']
# Out:
# [{'id': '8359',
#   'rank': '1',
#   'name': 'Babar Azam',
#   'country': 'Pakistan',
#   'rating': '824',
#   'points': '824',
#   'lastUpdatedOn': '2024-04-16',
#   'trend': 'Flat',
#   'faceImageId': '352417',
#   'countryId': '3',
#   'avg': '56.72'},
#  {'id': '11808',
#   'rank': '2',
#   'name': 'Shubman Gill',
#   'country': 'India',
#   'rating': '801',
#   'points': '801',
#   'lastUpdatedOn': '2024-04-16',
#   'trend': 'Flat',
#   'faceImageId': '352479',
#   'countryId': '2',
#   'avg': '61.38'},
#  {'id': '1413',
#   'rank': '3',
#   'name': 'Virat Kohli',
#   'country': 'India',
#   'rating': '768',
#   'points': '768',
#   'lastUpdatedOn': '2024-04-16',
#   'trend': 'Flat',
#   'faceImageId': '332891',
#   'countryId': '2',
#   'avg': '58.68'},
#  {'id': '576',
#   'rank': '4',
#   'name': 'Rohit Sharma',
#   'country': 'India',
#   'rating': '746',
#   'points': '746',
#   'lastUpdatedOn': '2024-04-16',
#   'trend': 'Flat',
#   'faceImageId': '352478',
# ...

# %%
pd.DataFrame.from_dict(response_data['rank']).drop(columns=['id','trend'])
# Out:
#    rank                   name       country rating points lastUpdatedOn  \
# 0     1             Babar Azam      Pakistan    824    824    2024-04-16
# 1     2           Shubman Gill         India    801    801    2024-04-16
# 2     3            Virat Kohli         India    768    768    2024-04-16
# 3     4           Rohit Sharma         India    746    746    2024-04-16
# 4     4           Harry Tector       Ireland    746    746    2024-04-16
# 5     6         Daryl Mitchell   New Zealand    728    728    2024-04-16
# 6     7           David Warner     Australia    723    723    2024-04-16
# 7     8        Pathum Nissanka     Sri Lanka    711    711    2024-04-16
# 8     9            Dawid Malan       England    707    707    2024-04-16
# 9    10  Rassie van der Dussen  South Africa    701    701    2024-04-16
# 10   11       Heinrich Klaasen  South Africa    697    697    2024-04-16
# 11   12           Shreyas Iyer         India    689    689    2024-04-16
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 pd.read_json(response_data['rank'])
#
# File c:\Users\65859\.conda\envs\practice\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\65859\.conda\envs\practice\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# ...
